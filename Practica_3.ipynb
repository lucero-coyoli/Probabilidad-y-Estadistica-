# %% [markdown]
# <a href="https://colab.research.google.com/github/lucero-coyoli/Probabilidad-y-Estadistica-/blob/main/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estadistìca Descriptiva
# ### Unidad I
# ### Practica 3
# ### Alumno: Lucero Rodriguez Coyoli
# ### No. de Control: 24041227
# ### 10/02/2025

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1=[]
for i in range (100):
  numero_aleatorio=round (random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [75.06, 95.14, 87.81, 56.43, 66.09, 99.89, 73.43, 88.83, 80.75, 78.52, 68.3, 82.83, 60.53, 70.23, 61.94, 94.82, 89.38, 98.73, 52.72, 90.34, 87.32, 98.08, 71.78, 76.93, 57.07, 76.18, 62.2, 86.09, 60.75, 91.34, 90.23, 83.05, 59.85, 70.37, 84.91, 64.78, 50.65, 50.88, 81.95, 58.22, 53.24, 77.14, 66.26, 53.35, 85.57, 67.96, 62.91, 63.08, 62.92, 77.98, 70.88, 54.8, 86.19, 70.37, 72.26, 74.32, 56.61, 51.29, 96.86, 93.91, 58.56, 99.37, 92.67, 98.22, 60.72, 71.55, 74.27, 77.74, 81.79, 95.84, 72.86, 52.35, 86.53, 67.08, 92.56, 63.86, 64.64, 99.19, 56.66, 58.12, 95.73, 91.7, 56.13, 97.93, 81.35, 88.08, 74.2, 51.91, 94.7, 61.49, 52.31, 69.29, 84.35, 57.59, 86.41, 53.05, 72.83, 98.66, 60.31, 60.21]

# %%
fabrica2=[]
for i in range (100):
  numero_aleatorio2=round (random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [51.32, 87.53, 77.17, 68.88, 91.4, 55.85, 93.01, 67.18, 73.81, 75.09, 52.72, 89.38, 93.72, 88.23, 51.34, 86.81, 93.06, 62.37, 81.44, 96.84, 59.96, 76.61, 88.94, 79.25, 98.48, 56.56, 94.81, 65.91, 84.87, 62.29, 77.25, 59.16, 71.2, 75.12, 98.64, 65.7, 53.42, 57.3, 78.3, 63.57, 90.96, 80.57, 93.16, 74.34, 89.32, 82.46, 76.49, 73.45, 70.54, 69.88, 96.15, 75.67, 66.23, 70.76, 91.38, 81.93, 64.57, 71.68, 98.03, 94.88, 63.35, 82.21, 73.21, 66.48, 86.52, 70.11, 68.18, 92.38, 86.05, 85.02, 85.66, 94.71, 98.46, 92.07, 55.38, 83.71, 51.74, 75.09, 77.15, 50.9, 84.12, 75.42, 74.96, 87.07, 69.78, 74.68, 98.69, 53.32, 94.39, 52.46, 79.02, 85.39, 57.09, 93.21, 92.13, 94.13, 59.77, 59.69, 93.9, 67.04]

# %%
maximo1= max(fabrica1)
minimo1= min(fabrica1)
rango1= maximo1-minimo1
media1= mean(fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)

print ("Estadistica descriptiva de la Fabrica 1\n","Media =", media1,
       "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo =", maximo1,
       "\n Minimo =", minimo1, "\n Rango =", rango1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 67.33055
#  Mediana = 60.21
#  Moda = 60.21
#  Maximo = 99.89
#  Minimo = 50.65
#  Rango = 49.24

# %%
maximo2= max(fabrica2)
minimo2= min(fabrica2)
rango2= maximo2-minimo2
media2= mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)

print ("Estadistica descriptiva de la Fabrica 2\n","Media =", media2,
       "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2,
       "\n Minimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 77.0158
#  Mediana = 76.88
#  Moda = 75.09
#  Maximo = 98.69
#  Minimo = 50.9
#  Rango = 47.79

# %% [markdown]
# ## Dispersiòn de los Datos

# %%
desviacion_estandar_fabrica1= stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 12.814326279107974

# %%
desviacion_estandar_fabrica2=stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 14.020075229988798

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline (moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor="black")

plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Densidad

# %%
import seaborn as sns

# %%
#La densidad gráfica es una forma de visualizar la distribución de datos en

# un intervalo o periodo de tiempo continuo.

#Se basa en un histograma que usa el suavizado de kernel para trazar valores,

# lo que permite obtener distribuciones más suaves al reducir el ruido.

#Una curva de densidad muestra la ubicación de la media y la mediana de una distribución.

sns.histplot(x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10 )
# Out:
# <Axes: ylabel='Count'>
